# %%
# Import dependencies
import pandas as pd
from datetime import datetime, timedelta
import re
import os
import glob

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Concatenating All DataFrames

# %%
raceNames = [
    'Bahrain',
    'Saudi Arabia',
    'Australia',
    'Emilia Romagna',
    'Miami',
    'Spain',
    'Monaco',
    'Azerbaijan',
    'Canada',
    'Great Britain',
    'Austria',
    'France',
    'Hungary'
]

# %%
master_df = pd.DataFrame()
race_df_list = []

# %%
# use glob to get all the csv files 
# in the folder
csv_files = glob.glob(os.path.join('./data', "*.csv"))
csv_files.sort()
csv_files
# Out:
# ['./data/00_0_df.csv',
#  './data/00_1_df.csv',
#  './data/00_2_df.csv',
#  './data/00_3_df.csv',
#  './data/00_4_df.csv',
#  './data/00_5_df.csv',
#  './data/00_6_df.csv',
#  './data/00_7_df.csv',
#  './data/01_0_df.csv',
#  './data/01_1_df.csv',
#  './data/01_2_df.csv',
#  './data/01_3_df.csv',
#  './data/01_4_df.csv',
#  './data/01_5_df.csv',
#  './data/01_6_df.csv',
#  './data/01_7_df.csv',
#  './data/02_0_df.csv',
#  './data/02_1_df.csv',
#  './data/02_2_df.csv',
#  './data/02_3_df.csv',
#  './data/02_4_df.csv',
#  './data/02_5_df.csv',
#  './data/02_6_df.csv',
#  './data/02_7_df.csv',
#  './data/03_0_df.csv',
#  './data/03_1_df.csv',
#  './data/03_2_df.csv',
#  './data/03_3_df.csv',
#  './data/03_4_df.csv',
#  './data/03_5_df.csv',
#  './data/03_6_df.csv',
#  './data/03_7_df.csv',
#  './data/03_8_df.csv',
#  './data/04_0_df.csv',
#  './data/04_1_df.csv',
#  './data/04_2_df.csv',
#  './data/04_3_df.csv',
#  './data/04_4_df.csv',
#  './data/04_5_df.csv',
#  './data/04_6_df.csv',
#  './data/04_7_df.csv',
#  './data/05_0_df.csv',
#  './data/05_1_df.csv',
#  './data/05_2_df.csv',
#  './data/05_3_df.csv',
#  './data/05_4_df.csv',
#  './data/05_5_df.csv',
#  './data/05_6_df.csv',
#  './data/05_7_df.csv',
#  './data/06_0_df.csv',
#  './data/06_1_df.csv',
#  './data/06_2_df.csv',
#  './data/06_3_df.csv',
#  './data/06_4_df.csv',
#  './data/06_5_df.csv',
#  './data/06_6_df.csv',
#  './data/06_7_df.csv',
#  './data/07_0_df.csv',
#  './data/07_1_df.csv',
#  './data/07_2_df.csv',
#  './data/07_3_df.csv',
#  './data/07_4_df.csv',
#  './data/07_5_df.csv',
#  './data/07_6_df.csv',
#  './data/07_7_df.csv',
#  './data/08_0_df.csv',
#  './data/08_1_df.csv',
#  './data/08_2_df.csv',
#  './data/08_3_df.csv',
#  './data/08_4_df.csv',
#  './data/08_5_df.csv',
#  './data/08_6_df.csv',
#  './data/08_7_df.csv',
#  './data/09_0_df.csv',
#  './data/09_1_df.csv',
#  './data/09_2_df.csv',
#  './data/09_3_df.csv',
#  './data/09_4_df.csv',
#  './data/09_5_df.csv',
#  './data/09_6_df.csv',
#  './data/09_7_df.csv',
#  './data/10_0_df.csv',
#  './data/10_1_df.csv',
#  './data/10_2_df.csv',
#  './data/10_3_df.csv',
#  './data/10_4_df.csv',
#  './data/10_5_df.csv',
#  './data/10_6_df.csv',
#  './data/10_7_df.csv',
#  './data/10_8_df.csv',
#  './data/11_0_df.csv',
#  './data/11_1_df.csv',
#  './data/11_2_df.csv',
#  './data/11_3_df.csv',
#  './data/11_4_df.csv',
#  './data/11_5_df.csv',
#  './data/11_6_df.csv',
#  './data/11_7_df.csv',
#  './data/12_0_df.csv',
#  './data/12_1_df.csv',
#  './data/12_2_df.csv',
#  './data/12_3_df.csv',
#  './data/12_4_df.csv',
#  './data/12_5_df.csv',
#  './data/12_6_df.csv',
#  './data/12_7_df.csv']

# %%
# loop over the list of csv files, converting >100 tables into individual race dataframes
for count, fileLocation in enumerate(csv_files):
      
    # read the csv file
    df = pd.read_csv(fileLocation)
      
    # print the location and filename
    print('Location:', fileLocation)
    fileName = fileLocation.split("/")[-1]
    raceIndex = fileName[0:2]
    tableIndex = int(fileName[3])
    print('File Name:', fileName)
    print(f'Race Number Index: {raceIndex}')
    print(f'Table Number Index: {tableIndex}')
    
    # Races 3 and 10 have sprints and need to be concatted differently
    if (raceIndex == '03') or (raceIndex == '10'):
        if fileName == f'{raceIndex}_0_df.csv':
            master_df['Final Race Position'] = df['Pos']
            master_df['No'] = df['No']
            master_df['Driver Name'] = df['Driver']
            master_df['Car'] = df['Car']
            master_df['Race Laps'] = df['Laps']
            master_df['Race Time'] = df['Time/Retired']
            master_df['Race Points'] = df['PTS']
            master_df['Race'] = raceNames[int(raceIndex)]
            master_df.set_index('No', inplace=True)
        elif fileName == f'{raceIndex}_1_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
            master_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)
        elif fileName == f'{raceIndex}_2_df.csv':
            df.set_index('No', inplace=True)
            df.sort_values(by=['Driver', 'Stops'])
            df.drop_duplicates(subset=['Driver'], keep='last', inplace=True)
            master_df = master_df.join(df[['Stops', 'Total']], on='No')
            master_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
        elif fileName == f'{raceIndex}_3_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Pos']], on='No')
            master_df.rename(columns={"Pos": "Starting Grid Pos"}, inplace=True)
        elif fileName == f'{raceIndex}_4_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Pos', 'Laps', 'Time/Retired', 'PTS']], on='No')
            master_df.rename(columns={"Pos": "Final Sprint Postition", "Laps": "Sprint Laps", "Time/Retired": "Sprint Time/Retired", "PTS": "Sprint PTS"}, inplace=True)
        elif fileName == f'{raceIndex}_5_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Pos', 'Time']], on='No')
            master_df.rename(columns={"Pos": "Starting Sprint Postition", "Time": "Sprint Grid Time"}, inplace=True)
        elif fileName == f'{raceIndex}_6_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Pos', 'Time', 'Gap', 'Laps']], on='No')
            master_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)
        elif fileName == f'{raceIndex}_7_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
            master_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)
        elif fileName == f'{raceIndex}_8_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Pos', 'Time', 'Gap', 'Laps']], on='No')
            master_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)
        else:
            print("SOMETHING WENT WRONG")
    else:
        if fileName == f'{raceIndex}_0_df.csv':
            master_df['Final Race Position'] = df['Pos']
            master_df['No'] = df['No']
            master_df['Driver Name'] = df['Driver']
            master_df['Car'] = df['Car']
            master_df['Race Laps'] = df['Laps']
            master_df['Race Time'] = df['Time/Retired']
            master_df['Race Points'] = df['PTS']
            master_df['Race'] = raceNames[int(raceIndex)]
            master_df.set_index('No', inplace=True)
        elif fileName == f'{raceIndex}_1_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
            master_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)
        elif fileName == f'{raceIndex}_2_df.csv':
            df.set_index('No', inplace=True)
            df.sort_values(by=['Driver', 'Stops'])
            df.drop_duplicates(subset=['Driver'], keep='last', inplace=True)
            master_df = master_df.join(df[['Stops', 'Total']], on='No')
            master_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)
        elif fileName == f'{raceIndex}_3_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Pos', 'Time']], on='No')
            master_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)
        elif fileName == f'{raceIndex}_4_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
            master_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)
        elif fileName == f'{raceIndex}_5_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Pos', 'Time', 'Gap', 'Laps']], on='No')
            master_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)
        elif fileName == f'{raceIndex}_6_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Pos', 'Time', 'Gap', 'Laps']], on='No')
            master_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)
        elif fileName == f'{raceIndex}_7_df.csv':
            df.set_index('No', inplace=True)
            master_df = master_df.join(df[['Pos', 'Time', 'Gap', 'Laps']], on='No')
            master_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)
        else:
            print("SOMETHING WENT WRONG")
            
    # The sprint races have one more raceIndex, so the master_df needs to be reset at 7 and 8    
    if (raceIndex != '03' and raceIndex != '10') and (tableIndex == 7):
        master_df.reset_index(inplace=True)
        race_df_list.append(master_df)
        print(f"{raceNames[int(raceIndex)]}_DF has been added successfully")
        print()
        master_df = pd.DataFrame()
    elif (tableIndex == 8):
        master_df.reset_index(inplace=True)
        race_df_list.append(master_df)
        print(f"{raceNames[int(raceIndex)]}_DF has been added successfully")
        print()
        master_df = pd.DataFrame()
# Out:
# Location: ./data/00_0_df.csv
# File Name: 00_0_df.csv
# Race Number Index: 00
# Table Number Index: 0
# Location: ./data/00_1_df.csv
# File Name: 00_1_df.csv
# Race Number Index: 00
# Table Number Index: 1
# Location: ./data/00_2_df.csv
# File Name: 00_2_df.csv
# Race Number Index: 00
# Table Number Index: 2
# Location: ./data/00_3_df.csv
# File Name: 00_3_df.csv
# Race Number Index: 00
# Table Number Index: 3
# Location: ./data/00_4_df.csv
# File Name: 00_4_df.csv
# Race Number Index: 00
# Table Number Index: 4
# Location: ./data/00_5_df.csv
# File Name: 00_5_df.csv
# Race Number Index: 00
# Table Number Index: 5
# Location: ./data/00_6_df.csv
# File Name: 00_6_df.csv
# Race Number Index: 00
# Table Number Index: 6
# Location: ./data/00_7_df.csv
# File Name: 00_7_df.csv
# Race Number Index: 00
# Table Number Index: 7
# Bahrain_DF has been added successfully
#
# Location: ./data/01_0_df.csv
# File Name: 01_0_df.csv
# Race Number Index: 01
# Table Number Index: 0
# Location: ./data/01_1_df.csv
# File Name: 01_1_df.csv
# Race Number Index: 01
# Table Number Index: 1
# Location: ./data/01_2_df.csv
# File Name: 01_2_df.csv
# Race Number Index: 01
# Table Number Index: 2
# Location: ./data/01_3_df.csv
# File Name: 01_3_df.csv
# Race Number Index: 01
# Table Number Index: 3
# Location: ./data/01_4_df.csv
# File Name: 01_4_df.csv
# Race Number Index: 01
# Table Number Index: 4
# Location: ./data/01_5_df.csv
# File Name: 01_5_df.csv
# Race Number Index: 01
# Table Number Index: 5
# Location: ./data/01_6_df.csv
# File Name: 01_6_df.csv
# Race Number Index: 01
# Table Number Index: 6
# Location: ./data/01_7_df.csv
# File Name: 01_7_df.csv
# Race Number Index: 01
# Table Number Index: 7
# Saudi Arabia_DF has been added successfully
#
# Location: ./data/02_0_df.csv
# File Name: 02_0_df.csv
# Race Number Index: 02
# Table Number Index: 0
# Location: ./data/02_1_df.csv
# File Name: 02_1_df.csv
# Race Number Index: 02
# Table Number Index: 1
# Location: ./data/02_2_df.csv
# File Name: 02_2_df.csv
# Race Number Index: 02
# Table Number Index: 2
# Location: ./data/02_3_df.csv
# File Name: 02_3_df.csv
# Race Number Index: 02
# Table Number Index: 3
# Location: ./data/02_4_df.csv
# File Name: 02_4_df.csv
# Race Number Index: 02
# Table Number Index: 4
# Location: ./data/02_5_df.csv
# File Name: 02_5_df.csv
# Race Number Index: 02
# Table Number Index: 5
# Location: ./data/02_6_df.csv
# File Name: 02_6_df.csv
# Race Number Index: 02
# Table Number Index: 6
# Location: ./data/02_7_df.csv
# File Name: 02_7_df.csv
# Race Number Index: 02
# Table Number Index: 7
# Australia_DF has been added successfully
#
# Location: ./data/03_0_df.csv
# File Name: 03_0_df.csv
# Race Number Index: 03
# Table Number Index: 0
# Location: ./data/03_1_df.csv
# File Name: 03_1_df.csv
# Race Number Index: 03
# Table Number Index: 1
# Location: ./data/03_2_df.csv
# File Name: 03_2_df.csv
# Race Number Index: 03
# Table Number Index: 2
# Location: ./data/03_3_df.csv
# File Name: 03_3_df.csv
# Race Number Index: 03
# Table Number Index: 3
# Location: ./data/03_4_df.csv
# File Name: 03_4_df.csv
# Race Number Index: 03
# Table Number Index: 4
# Location: ./data/03_5_df.csv
# File Name: 03_5_df.csv
# Race Number Index: 03
# Table Number Index: 5
# Location: ./data/03_6_df.csv
# File Name: 03_6_df.csv
# Race Number Index: 03
# Table Number Index: 6
# Location: ./data/03_7_df.csv
# File Name: 03_7_df.csv
# Race Number Index: 03
# Table Number Index: 7
# Location: ./data/03_8_df.csv
# File Name: 03_8_df.csv
# Race Number Index: 03
# Table Number Index: 8
# Emilia Romagna_DF has been added successfully
#
# Location: ./data/04_0_df.csv
# File Name: 04_0_df.csv
# Race Number Index: 04
# Table Number Index: 0
# Location: ./data/04_1_df.csv
# File Name: 04_1_df.csv
# Race Number Index: 04
# Table Number Index: 1
# Location: ./data/04_2_df.csv
# File Name: 04_2_df.csv
# Race Number Index: 04
# Table Number Index: 2
# Location: ./data/04_3_df.csv
# File Name: 04_3_df.csv
# Race Number Index: 04
# Table Number Index: 3
# Location: ./data/04_4_df.csv
# File Name: 04_4_df.csv
# Race Number Index: 04
# Table Number Index: 4
# Location: ./data/04_5_df.csv
# File Name: 04_5_df.csv
# Race Number Index: 04
# Table Number Index: 5
# Location: ./data/04_6_df.csv
# File Name: 04_6_df.csv
# Race Number Index: 04
# Table Number Index: 6
# Location: ./data/04_7_df.csv
# File Name: 04_7_df.csv
# Race Number Index: 04
# Table Number Index: 7
# Miami_DF has been added successfully
#
# Location: ./data/05_0_df.csv
# File Name: 05_0_df.csv
# Race Number Index: 05
# Table Number Index: 0
# Location: ./data/05_1_df.csv
# File Name: 05_1_df.csv
# Race Number Index: 05
# Table Number Index: 1
# Location: ./data/05_2_df.csv
# File Name: 05_2_df.csv
# Race Number Index: 05
# Table Number Index: 2
# Location: ./data/05_3_df.csv
# File Name: 05_3_df.csv
# Race Number Index: 05
# Table Number Index: 3
# Location: ./data/05_4_df.csv
# File Name: 05_4_df.csv
# Race Number Index: 05
# Table Number Index: 4
# Location: ./data/05_5_df.csv
# File Name: 05_5_df.csv
# Race Number Index: 05
# Table Number Index: 5
# Location: ./data/05_6_df.csv
# File Name: 05_6_df.csv
# Race Number Index: 05
# Table Number Index: 6
# Location: ./data/05_7_df.csv
# File Name: 05_7_df.csv
# Race Number Index: 05
# Table Number Index: 7
# Spain_DF has been added successfully
#
# Location: ./data/06_0_df.csv
# File Name: 06_0_df.csv
# Race Number Index: 06
# Table Number Index: 0
# Location: ./data/06_1_df.csv
# File Name: 06_1_df.csv
# Race Number Index: 06
# Table Number Index: 1
# Location: ./data/06_2_df.csv
# File Name: 06_2_df.csv
# Race Number Index: 06
# Table Number Index: 2
# Location: ./data/06_3_df.csv
# File Name: 06_3_df.csv
# Race Number Index: 06
# Table Number Index: 3
# Location: ./data/06_4_df.csv
# File Name: 06_4_df.csv
# Race Number Index: 06
# Table Number Index: 4
# Location: ./data/06_5_df.csv
# File Name: 06_5_df.csv
# Race Number Index: 06
# Table Number Index: 5
# Location: ./data/06_6_df.csv
# File Name: 06_6_df.csv
# Race Number Index: 06
# Table Number Index: 6
# Location: ./data/06_7_df.csv
# File Name: 06_7_df.csv
# Race Number Index: 06
# Table Number Index: 7
# Monaco_DF has been added successfully
#
# Location: ./data/07_0_df.csv
# File Name: 07_0_df.csv
# Race Number Index: 07
# Table Number Index: 0
# Location: ./data/07_1_df.csv
# File Name: 07_1_df.csv
# Race Number Index: 07
# Table Number Index: 1
# Location: ./data/07_2_df.csv
# File Name: 07_2_df.csv
# Race Number Index: 07
# Table Number Index: 2
# Location: ./data/07_3_df.csv
# File Name: 07_3_df.csv
# Race Number Index: 07
# Table Number Index: 3
# Location: ./data/07_4_df.csv
# File Name: 07_4_df.csv
# Race Number Index: 07
# Table Number Index: 4
# Location: ./data/07_5_df.csv
# File Name: 07_5_df.csv
# Race Number Index: 07
# Table Number Index: 5
# Location: ./data/07_6_df.csv
# File Name: 07_6_df.csv
# Race Number Index: 07
# Table Number Index: 6
# Location: ./data/07_7_df.csv
# File Name: 07_7_df.csv
# Race Number Index: 07
# Table Number Index: 7
# Azerbaijan_DF has been added successfully
#
# Location: ./data/08_0_df.csv
# File Name: 08_0_df.csv
# Race Number Index: 08
# Table Number Index: 0
# Location: ./data/08_1_df.csv
# File Name: 08_1_df.csv
# Race Number Index: 08
# Table Number Index: 1
# Location: ./data/08_2_df.csv
# File Name: 08_2_df.csv
# Race Number Index: 08
# Table Number Index: 2
# Location: ./data/08_3_df.csv
# File Name: 08_3_df.csv
# Race Number Index: 08
# Table Number Index: 3
# Location: ./data/08_4_df.csv
# File Name: 08_4_df.csv
# Race Number Index: 08
# Table Number Index: 4
# Location: ./data/08_5_df.csv
# File Name: 08_5_df.csv
# Race Number Index: 08
# Table Number Index: 5
# Location: ./data/08_6_df.csv
# File Name: 08_6_df.csv
# Race Number Index: 08
# Table Number Index: 6
# Location: ./data/08_7_df.csv
# File Name: 08_7_df.csv
# Race Number Index: 08
# Table Number Index: 7
# Canada_DF has been added successfully
#
# Location: ./data/09_0_df.csv
# File Name: 09_0_df.csv
# Race Number Index: 09
# Table Number Index: 0
# Location: ./data/09_1_df.csv
# File Name: 09_1_df.csv
# Race Number Index: 09
# Table Number Index: 1
# Location: ./data/09_2_df.csv
# File Name: 09_2_df.csv
# Race Number Index: 09
# Table Number Index: 2
# Location: ./data/09_3_df.csv
# File Name: 09_3_df.csv
# Race Number Index: 09
# Table Number Index: 3
# Location: ./data/09_4_df.csv
# File Name: 09_4_df.csv
# Race Number Index: 09
# Table Number Index: 4
# Location: ./data/09_5_df.csv
# File Name: 09_5_df.csv
# Race Number Index: 09
# Table Number Index: 5
# Location: ./data/09_6_df.csv
# File Name: 09_6_df.csv
# Race Number Index: 09
# Table Number Index: 6
# Location: ./data/09_7_df.csv
# File Name: 09_7_df.csv
# Race Number Index: 09
# Table Number Index: 7
# Great Britain_DF has been added successfully
# Location: ./data/10_0_df.csv
# File Name: 10_0_df.csv
# Race Number Index: 10
# Table Number Index: 0
# Location: ./data/10_1_df.csv
# File Name: 10_1_df.csv
# Race Number Index: 10
# Table Number Index: 1
# Location: ./data/10_2_df.csv
# File Name: 10_2_df.csv
# Race Number Index: 10
# Table Number Index: 2
# Location: ./data/10_3_df.csv
# File Name: 10_3_df.csv
# Race Number Index: 10
# Table Number Index: 3
# Location: ./data/10_4_df.csv
# File Name: 10_4_df.csv
# Race Number Index: 10
# Table Number Index: 4
# Location: ./data/10_5_df.csv
# File Name: 10_5_df.csv
# Race Number Index: 10
# Table Number Index: 5
# Location: ./data/10_6_df.csv
# File Name: 10_6_df.csv
# Race Number Index: 10
# Table Number Index: 6
# Location: ./data/10_7_df.csv
# File Name: 10_7_df.csv
# Race Number Index: 10
# Table Number Index: 7
# Location: ./data/10_8_df.csv
# File Name: 10_8_df.csv
# Race Number Index: 10
# Table Number Index: 8
# Austria_DF has been added successfully
#
# Location: ./data/11_0_df.csv
# File Name: 11_0_df.csv
# Race Number Index: 11
# Table Number Index: 0
# Location: ./data/11_1_df.csv
# File Name: 11_1_df.csv
# Race Number Index: 11
# Table Number Index: 1
# Location: ./data/11_2_df.csv
# File Name: 11_2_df.csv
# Race Number Index: 11
# Table Number Index: 2
# Location: ./data/11_3_df.csv
# File Name: 11_3_df.csv
# Race Number Index: 11
# Table Number Index: 3
# Location: ./data/11_4_df.csv
# File Name: 11_4_df.csv
# Race Number Index: 11
# Table Number Index: 4
# Location: ./data/11_5_df.csv
# File Name: 11_5_df.csv
# Race Number Index: 11
# Table Number Index: 5
# Location: ./data/11_6_df.csv
# File Name: 11_6_df.csv
# Race Number Index: 11
# Table Number Index: 6
# Location: ./data/11_7_df.csv
# File Name: 11_7_df.csv
# Race Number Index: 11
# Table Number Index: 7
# France_DF has been added successfully
#
# Location: ./data/12_0_df.csv
# File Name: 12_0_df.csv
# Race Number Index: 12
# Table Number Index: 0
# Location: ./data/12_1_df.csv
# File Name: 12_1_df.csv
# Race Number Index: 12
# Table Number Index: 1
# Location: ./data/12_2_df.csv
# File Name: 12_2_df.csv
# Race Number Index: 12
# Table Number Index: 2
# Location: ./data/12_3_df.csv
# File Name: 12_3_df.csv
# Race Number Index: 12
# Table Number Index: 3
# Location: ./data/12_4_df.csv
# File Name: 12_4_df.csv
# Race Number Index: 12
# Table Number Index: 4
# Location: ./data/12_5_df.csv
# File Name: 12_5_df.csv
# Race Number Index: 12
# Table Number Index: 5
# Location: ./data/12_6_df.csv
# File Name: 12_6_df.csv
# Race Number Index: 12
# Table Number Index: 6
# Location: ./data/12_7_df.csv
# File Name: 12_7_df.csv
# Race Number Index: 12
# Table Number Index: 7
# Hungary_DF has been added successfully

# %%
# Concat the race DataFrames into one F1 DataFrame
f1_df = pd.concat(race_df_list, axis=0, ignore_index=True)

# %%
# Set index to the Race and Driver No
# f1_df.set_index(['Race', 'No'], inplace=False)

# %%
# Save f1_df to csv file
# f1_df.to_csv(f'./f1_df.csv', index=False)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Filling Null Values

# %%
master_df = f1_df.copy()

# %%
# Fill NaN values
master_df['Starting Grid Pos'] = master_df['Starting Grid Pos'].fillna(99)

master_df['Fastest Lap No'] = master_df['Fastest Lap No'].fillna(0)
master_df['Time of day'] = master_df['Time of day'].fillna('99:99:99')
master_df['Fastest Lap Time'] = master_df['Fastest Lap Time'].fillna('99:99')
master_df['Avg Speed'] = master_df['Avg Speed'].fillna(0)

master_df['Stops'] = master_df['Stops'].fillna(99)
master_df['Total Pit Time'] = master_df['Total Pit Time'].fillna('99:99')

master_df['P1 Postition'] = master_df['P1 Postition'].fillna(99)
master_df['P1 Time'] = master_df['P1 Time'].fillna('99:99')
master_df['P1 Laps'] = master_df['P1 Laps'].fillna(0)

master_df['P2 Postition'] = master_df['P2 Postition'].fillna(99)
master_df['P2 Time'] = master_df['P2 Time'].fillna('99:99')
master_df['P2 Laps'] = master_df['P2 Laps'].fillna(0)

master_df['P3 Postition'] = master_df['P3 Postition'].fillna(99)
master_df['P3 Time'] = master_df['P3 Time'].fillna('99:99')
master_df['P3 Laps'] = master_df['P3 Laps'].fillna(0)

master_df['Starting Grid Quali Time'] = master_df['Starting Grid Quali Time'].fillna('99:99')
master_df['Q1'] = master_df['Q1'].fillna('99:99')
master_df['Q2'] = master_df['Q2'].fillna('99:99')
master_df['Q3'] = master_df['Q3'].fillna('99:99')

master_df['Sprint Laps'] = master_df['Sprint Laps'].fillna(0)
master_df['Sprint Time/Retired'] = master_df['Sprint Time/Retired'].fillna('0')
master_df['Sprint Grid Time'] = master_df['Sprint Grid Time'].fillna('00:00')
master_df['Sprint PTS'] = master_df['Sprint PTS'].fillna(0)
master_df['Starting Sprint Postition'] = master_df['Starting Sprint Postition'].fillna(0)
master_df['Final Sprint Postition'] = master_df['Final Sprint Postition'].fillna(0)

# %%
def formatPos(race):
    for i, value in enumerate(race):
        if (value == 'NC'):
            race.iloc[i] = 99
        else:
            race.iloc[i] = pd.to_numeric(value)
            
    return pd.to_numeric(race)

# %%
# Change NC to 99th place
racePos = master_df['Final Race Position']
racePos = formatPos(racePos)
master_df['Final Race Position'] = racePos

sprintPos = master_df['Final Sprint Postition']
sprintPos = formatPos(sprintPos)
master_df['Final Sprint Postition'] = sprintPos
# Out:
# /Users/zcvalis/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ## Strip Times of '+' and 's'

# %%
# Remove '+' and 's' from Race Time column
master_df['Race Time']= master_df['Race Time'].astype('str')
master_df['Race Time']= master_df['Race Time'].map(lambda x: x.lstrip('+-'))
master_df['Race Time']= master_df['Race Time'].map(lambda x: x.rstrip('s'))

# Remove '+' and 's' from P3 Gap column
master_df['P3 Gap']= master_df['P3 Gap'].astype('str')
master_df['P3 Gap']= master_df['P3 Gap'].map(lambda x: x.lstrip('+-'))
master_df['P3 Gap']= master_df['P3 Gap'].map(lambda x: x.rstrip('s'))

# Remove '+' and 's' from P2 Gap column
master_df['P2 Gap']= master_df['P2 Gap'].astype('str')
master_df['P2 Gap']= master_df['P2 Gap'].map(lambda x: x.lstrip('+-'))
master_df['P2 Gap']= master_df['P2 Gap'].map(lambda x: x.rstrip('s'))

# Remove '+' and 's' from P1 Gap column
master_df['P1 Gap']= master_df['P1 Gap'].astype('str')
master_df['P1 Gap']= master_df['P1 Gap'].map(lambda x: x.lstrip('+-'))
master_df['P1 Gap']= master_df['P1 Gap'].map(lambda x: x.rstrip('s'))

# Remove '+' and 's' from P1 Gap column
master_df['Sprint Time/Retired'] = master_df['Sprint Time/Retired'].astype('str')
master_df['Sprint Time/Retired'] = master_df['Sprint Time/Retired'].map(lambda x: x.lstrip('+-'))
master_df['Sprint Time/Retired'] = master_df['Sprint Time/Retired'].map(lambda x: x.rstrip('s'))

# %% [markdown]
# ## Convert All HH:MM:SS and MM:SS Times To Seconds

# %%
def raceTimeToSeconds(time):
    time_copy = time.copy()
    raceCount = 0
    for count, race in enumerate(time_copy):
        # Check to get the leading time for each race
        if (raceCount == 20):
            raceCount = 0
            
        # Race time is always first index
        if (raceCount == 0):
            end_time = race
            my_list = end_time.split(':')
            if len(my_list) == 3:
                time_f = timedelta(hours=int(my_list[0]),minutes=int(my_list[1]), seconds=float(my_list[2])).total_seconds()
                time_copy.iloc[count] = time_f
            elif len(my_list) == 2:
                time_f = timedelta(minutes=int(my_list[0]), seconds=float(my_list[1])).total_seconds()
                time_copy.iloc[count] = time_f
        # If race contains substring 'lap' indicating 1+ Lap. Will add the number of laps indicated so 1+ Lap 
        # Will add 1 whole lap, 2+ Lap will add two laps, etc.
        elif 'lap' in race:
            time_copy.iloc[count] = time_f+(int(race[0])*time_f)
        # Use regex to check if a float value exists
        elif re.match(r'^-?\d+(?:\.\d+)$', race) is not None:
            time_copy.iloc[count] = (time_f + float(race))
        # Anything else such as DNF, DSQ will get 999999
        elif (race== "DNF"):
            time_copy.iloc[count] = 999999
        elif (race== "DNS"):
            time_copy.iloc[count] = 0
            
        # Increment raceCount
        raceCount += 1
            
    return time_copy

# %%
race_time = master_df['Race Time']
new_race_time = raceTimeToSeconds(race_time)
master_df['Race Time'] = pd.to_numeric(new_race_time)

# %%
sprint_time = pd.DataFrame(master_df[['Race', 'Sprint Time/Retired']]).set_index(['Race'])
sprint_time.sort_values(by=['Sprint Time/Retired'])
print(sprint_time)
# new_sprint_time = raceTimeToSeconds(sprint_time)
# master_df['Sprint Time/Retired'] = new_sprint_time
# Out:
#                Sprint Time/Retired
# Race
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Bahrain                          0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Saudi Arabia                     0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Australia                        0
# Emilia Romagna           30:39.567
# Emilia Romagna               4.721
# Emilia Romagna              24.561
# Emilia Romagna              36.284
# Emilia Romagna              28.133
# Emilia Romagna               2.975
# Emilia Romagna              38.298
# Emilia Romagna              40.177
# Emilia Romagna              30.712
# Emilia Romagna              42.910
# Emilia Romagna              48.871
# Emilia Romagna              43.794
# Emilia Romagna              41.459
# Emilia Romagna              43.517
# Emilia Romagna                 DNF
# Emilia Romagna              52.017
# Emilia Romagna              33.773
# Emilia Romagna              27.740
# Emilia Romagna              32.278
# Emilia Romagna              17.578
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Miami                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Spain                            0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Monaco                           0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Azerbaijan                       0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Canada                           0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Great Britain                    0
# Austria                      1.675
# Austria                  26:30.059
# Austria                     35.447
# Austria                     13.429
# Austria                     31.032
# Austria                     37.163
# Austria                     38.580
# Austria                     34.539
# Austria                     39.738
# Austria                        DNS
# Austria                     37.557
# Austria                     52.412
# Austria                     48.241
# Austria                     50.753
# Austria                     52.125
# Austria                     54.556
# Austria                        DNF
# Austria                      5.644
# Austria                     68.694
# Austria                     18.302
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# France                           0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0
# Hungary                          0

# %%
def timeToSeconds(time):
    time_copy = time.copy()
    for count, race in enumerate(time_copy):
        # Check first if value is float (eg. time is already in seconds)
        if (race != "DNF"):
            if re.match(r'^-?\d+(?:\.\d+)$', str(race)) is not None:
                time_f = timedelta(seconds=float(race)).total_seconds()
                time_copy.iloc[count] = time_f
            else:
                end_time = race
                my_list = end_time.split(':')
                if len(my_list) == 3:
                    time_f = timedelta(hours=int(my_list[0]), minutes=int(my_list[1]), seconds=float(my_list[2])).total_seconds()
                    time_copy.iloc[count] = time_f
                elif len(my_list) == 2:
                    time_f = timedelta(minutes=int(my_list[0]), seconds=float(my_list[1])).total_seconds()
                    time_copy.iloc[count] = time_f
        # Anything else such as DNF, DSQ will get 999999
        else:
            time_copy.iloc[count] = 999999
            
    return time_copy

# %%
tod_time = master_df['Time of day']
new_tod_time = timeToSeconds(tod_time)
master_df['Time of day'] = new_tod_time

fastest_lap_copy = master_df['Fastest Lap Time']
new_fastlap_time = timeToSeconds(fastest_lap_copy)
master_df['Fastest Lap Time'] = new_fastlap_time

pit_time_copy = master_df['Total Pit Time']
new_pit_time = timeToSeconds(pit_time_copy)
master_df['Total Pit Time'] = new_pit_time

starting_grid_quali_copy = master_df['Starting Grid Quali Time']
new_quali_time = timeToSeconds(starting_grid_quali_copy)
master_df['Starting Grid Quali Time']= new_quali_time

Q1_copy = master_df['Q1']
new_q1_time = timeToSeconds(Q1_copy)
master_df['Q1'] = new_q1_time

Q2_copy = master_df['Q2']
new_q2_time = timeToSeconds(Q2_copy)
master_df['Q2'] = new_q2_time

Q3_copy = master_df['Q3']
new_q3_time = timeToSeconds(Q3_copy)
master_df['Q3'] = new_q3_time

P3_time_copy = master_df['P3 Time']
new_p3_time = timeToSeconds(P3_time_copy)
master_df['P3 Time'] = new_p3_time

P2_time_copy = master_df['P2 Time']
new_p2_time = timeToSeconds(P2_time_copy)
master_df['P2 Time'] = new_p2_time

P1_time_copy = master_df['P1 Time']
new_p1_time = timeToSeconds(P1_time_copy)
master_df['P1 Time'] = new_p1_time

Sprint_grid_time_copy = master_df['Sprint Grid Time']
new_sprint_grid_time = timeToSeconds(Sprint_grid_time_copy)
master_df['Sprint Grid Time'] = new_sprint_grid_time

# %%
def gapToNumeric(gap):
    for i, value in enumerate(gap):
        if (value == 'nan'):
            gap.iloc[i] = 999
        else:
            gap.iloc[i] = pd.to_numeric(value)

    return pd.to_numeric(gap)

# %%
p3Gap = master_df['P3 Gap']
new_p3Gap = gapToNumeric(p3Gap)
master_df['P3 Gap'] = new_p3Gap

p2Gap = master_df['P2 Gap']
new_p2Gap = gapToNumeric(p2Gap)
master_df['P2 Gap'] = new_p2Gap

p1Gap = master_df['P1 Gap']
new_p1Gap = gapToNumeric(p1Gap)
master_df['P1 Gap'] = new_p1Gap

# %%
master_df

# %%
# master_df.to_csv("master_1.csv", index=False)

# %%
master_df.dtypes
