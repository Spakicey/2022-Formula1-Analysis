# %%
# Import dependencies
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Bahrain Race 2022
# [Pos, No, Driver, Car, Race Laps, Time/Retired, Race PTS], [Fastest Lap, Time of day, Fastest Lap Time, Avg Speed], [Total Stops], [Starting Grid Position, Final Qualifying Time], [Q1 Time, Q2 Time, Q3 Time, Qualifying Laps]
bahrain_df = pd.DataFrame()

# Import race result data
df_0_0 = pd.read_csv("./data/0_0_df.csv")

bahrain_df['Final Race Position'] = df_0_0['Pos']
bahrain_df['No'] = df_0_0['No']
bahrain_df['Driver Name'] = df_0_0['Driver']
bahrain_df['Car'] = df_0_0['Car']
bahrain_df['Race Laps'] = df_0_0['Laps']
bahrain_df['Race Time'] = df_0_0['Time/Retired']
bahrain_df['Race Points'] = df_0_0['PTS']
bahrain_df.set_index('No', inplace=True)

df_0_1 = pd.read_csv("./data/0_1_df.csv")
df_0_1.set_index('No', inplace=True)

bahrain_df = bahrain_df.join(df_0_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
bahrain_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_0_2 = pd.read_csv("./data/0_2_df.csv")
df_0_2.set_index('No', inplace=True)
df_0_2.sort_values(by=['Driver', 'Stops'])
df_0_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

bahrain_df = bahrain_df.join(df_0_2[['Stops', 'Total']], on='No')
bahrain_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
bahrain_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)

df_0_3 = pd.read_csv("./data/0_3_df.csv")
df_0_3.set_index('No', inplace=True)

bahrain_df = bahrain_df.join(df_0_3[['Pos', 'Time']], on='No')
bahrain_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)


df_0_4 = pd.read_csv("./data/0_4_df.csv")
df_0_4.set_index('No', inplace=True)

bahrain_df = bahrain_df.join(df_0_4[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
bahrain_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)


df_0_5 = pd.read_csv("./data/0_5_df.csv")
df_0_5.set_index('No', inplace=True)

bahrain_df = bahrain_df.join(df_0_5[['Pos', 'Time', 'Gap', 'Laps']], on='No')
bahrain_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)


df_0_6 = pd.read_csv("./data/0_6_df.csv")
df_0_6.set_index('No', inplace=True)

bahrain_df = bahrain_df.join(df_0_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
bahrain_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_0_7 = pd.read_csv("./data/0_7_df.csv")
df_0_7.set_index('No', inplace=True)

bahrain_df = bahrain_df.join(df_0_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
bahrain_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

bahrain_df['Race'] = 'Bahrain'
bahrain_df.head(5)
# Out:
#    Final Race Position            Driver Name           Car  Race Laps  \
# No
# 16                   1  Charles  Leclerc  LEC       Ferrari         57
# 55                   2     Carlos  Sainz  SAI       Ferrari         57
# 44                   3   Lewis  Hamilton  HAM      Mercedes         57
# 63                   4   George  Russell  RUS      Mercedes         57
# 20                   5  Kevin  Magnussen  MAG  Haas Ferrari         57
#
#       Race Time  Race Points  Fastest Lap No Time of day Fastest Lap Time  \
# No
# 16  1:37:33.584           26              51    19:31:35         1:34.570
# 55      +5.598s           18              52    19:33:13         1:35.740
# 44      +9.675s           15              53    19:34:51         1:36.228
# 63     +11.211s           12              56    19:39:42         1:36.302
# 20     +14.754s           10              53    19:34:54         1:36.623
#
#     Avg Speed  Stops Total Pit Time  Starting Grid Pos  \
# No
# ...

# %%
# Saudi Arabia Race 2022
# [Pos, No, Driver, Car, Race Laps, Time/Retired, Race PTS], [Fastest Lap, Time of day, Fastest Lap Time, Avg Speed], [Total Stops], [Starting Grid Position, Final Qualifying Time], [Q1 Time, Q2 Time, Q3 Time, Qualifying Laps]
saudi_arabia_df = pd.DataFrame()

# Import race result data
df_1_0 = pd.read_csv("./data/1_0_df.csv")

saudi_arabia_df['Final Race Position'] = df_1_0['Pos']
saudi_arabia_df['No'] = df_1_0['No']
saudi_arabia_df['Driver Name'] = df_1_0['Driver']
saudi_arabia_df['Car'] = df_1_0['Car']
saudi_arabia_df['Race Laps'] = df_1_0['Laps']
saudi_arabia_df['Race Time'] = df_1_0['Time/Retired']
saudi_arabia_df['Race Points'] = df_1_0['PTS']
saudi_arabia_df.set_index('No', inplace=True)

df_1_1 = pd.read_csv("./data/1_1_df.csv")
df_1_1.set_index('No', inplace=True)

saudi_arabia_df = saudi_arabia_df.join(df_1_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
saudi_arabia_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_1_2 = pd.read_csv("./data/1_2_df.csv")
df_1_2.set_index('No', inplace=True)
df_1_2.sort_values(by=['Driver', 'Stops'])
df_1_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

saudi_arabia_df = saudi_arabia_df.join(df_1_2[['Stops', 'Total']], on='No')
saudi_arabia_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
saudi_arabia_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)

df_1_3 = pd.read_csv("./data/1_3_df.csv")
df_1_3.set_index('No', inplace=True)

saudi_arabia_df = saudi_arabia_df.join(df_1_3[['Pos', 'Time']], on='No')
saudi_arabia_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)


df_1_4 = pd.read_csv("./data/1_4_df.csv")
df_1_4.set_index('No', inplace=True)

saudi_arabia_df = saudi_arabia_df.join(df_1_4[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
saudi_arabia_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)


df_1_5 = pd.read_csv("./data/1_5_df.csv")
df_1_5.set_index('No', inplace=True)

saudi_arabia_df = saudi_arabia_df.join(df_1_5[['Pos', 'Time', 'Gap', 'Laps']], on='No')
saudi_arabia_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)


df_1_6 = pd.read_csv("./data/1_6_df.csv")
df_1_6.set_index('No', inplace=True)

saudi_arabia_df = saudi_arabia_df.join(df_1_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
saudi_arabia_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_1_7 = pd.read_csv("./data/1_7_df.csv")
df_1_7.set_index('No', inplace=True)

saudi_arabia_df = saudi_arabia_df.join(df_1_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
saudi_arabia_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

saudi_arabia_df['Race'] = 'Saudi Arabia'

saudi_arabia_df.head(5)
# Out:
#    Final Race Position            Driver Name                   Car  \
# No
# 1                    1   Max  Verstappen  VER  Red Bull Racing RBPT
# 16                   2  Charles  Leclerc  LEC               Ferrari
# 55                   3     Carlos  Sainz  SAI               Ferrari
# 11                   4     Sergio  Perez  PER  Red Bull Racing RBPT
# 63                   5   George  Russell  RUS              Mercedes
#
#     Race Laps    Race Time  Race Points  Fastest Lap No Time of day  \
# No
# 1          50  1:24:19.293           25            50.0    21:27:46
# 16         50      +0.549s           19            48.0    21:24:43
# 55         50      +8.097s           15            48.0    21:24:50
# 11         50     +10.800s           12            46.0    21:21:47
# 63         50     +32.732s           10            43.0    21:17:24
#
#    Fastest Lap Time  Avg Speed  Stops  Total Pit Time  Starting Grid Pos  \
# No
# ...

# %%
# Australia Race 2022
# [Pos, No, Driver, Car, Race Laps, Time/Retired, Race PTS], [Fastest Lap, Time of day, Fastest Lap Time, Avg Speed], [Total Stops], [Starting Grid Position, Final Qualifying Time], [Q1 Time, Q2 Time, Q3 Time, Qualifying Laps]
australia_df = pd.DataFrame()

# Import race result data
df_2_0 = pd.read_csv("./data/2_0_df.csv")

australia_df['Final Race Position'] = df_2_0['Pos']
australia_df['No'] = df_2_0['No']
australia_df['Driver Name'] = df_2_0['Driver']
australia_df['Car'] = df_2_0['Car']
australia_df['Race Laps'] = df_2_0['Laps']
australia_df['Race Time'] = df_2_0['Time/Retired']
australia_df['Race Points'] = df_2_0['PTS']
australia_df.set_index('No', inplace=True)

df_2_1 = pd.read_csv("./data/2_1_df.csv")
df_2_1.set_index('No', inplace=True)

australia_df = australia_df.join(df_2_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
australia_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_2_2 = pd.read_csv("./data/2_2_df.csv")
df_2_2.set_index('No', inplace=True)
df_2_2.sort_values(by=['Driver', 'Stops'])
df_2_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

australia_df = australia_df.join(df_2_2[['Stops', 'Total']], on='No')
australia_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
australia_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)

df_2_3 = pd.read_csv("./data/2_3_df.csv")
df_2_3.set_index('No', inplace=True)

australia_df = australia_df.join(df_2_3[['Pos', 'Time']], on='No')
australia_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)


df_2_4 = pd.read_csv("./data/2_4_df.csv")
df_2_4.set_index('No', inplace=True)

australia_df = australia_df.join(df_2_4[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
australia_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)


df_2_5 = pd.read_csv("./data/2_5_df.csv")
df_2_5.set_index('No', inplace=True)

australia_df = australia_df.join(df_2_5[['Pos', 'Time', 'Gap', 'Laps']], on='No')
australia_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)


df_2_6 = pd.read_csv("./data/2_6_df.csv")
df_2_6.set_index('No', inplace=True)

australia_df = australia_df.join(df_2_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
australia_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_2_7 = pd.read_csv("./data/2_7_df.csv")
df_2_7.set_index('No', inplace=True)

australia_df = australia_df.join(df_2_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
australia_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

australia_df['Race'] = 'Australia'

australia_df.head(5)
# Out:
#    Final Race Position            Driver Name                   Car  \
# No
# 16                   1  Charles  Leclerc  LEC               Ferrari
# 11                   2     Sergio  Perez  PER  Red Bull Racing RBPT
# 63                   3   George  Russell  RUS              Mercedes
# 44                   4   Lewis  Hamilton  HAM              Mercedes
# 4                    5     Lando  Norris  NOR      McLaren Mercedes
#
#     Race Laps    Race Time  Race Points  Fastest Lap No Time of day  \
# No
# 16         58  1:27:46.548           26            58.0    16:30:59
# 11         58     +20.524s           18            58.0    16:31:20
# 63         58     +25.593s           15            53.0    16:24:35
# 44         58     +28.543s           12            51.0    16:21:52
# 4          58     +53.303s           10            55.0    16:27:39
#
#    Fastest Lap Time  Avg Speed  Stops  Total Pit Time  Starting Grid Pos  \
# No
# ...

# %%
# Italy Race 2022

italy_df = pd.DataFrame()

df_3_0 = pd.read_csv("./data/3_0_df.csv")

italy_df['Final Race Position'] = df_3_0['Pos']
italy_df['No'] = df_3_0['No']
italy_df['Driver Name'] = df_3_0['Driver']
italy_df['Car'] = df_3_0['Car']
italy_df['Race Laps'] = df_3_0['Laps']
italy_df['Race Time'] = df_3_0['Time/Retired']
italy_df['Race Points'] = df_3_0['PTS']
italy_df.set_index('No', inplace=True)

df_3_1 = pd.read_csv("./data/3_1_df.csv")
df_3_1.set_index('No', inplace=True)

italy_df = italy_df.join(df_3_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
italy_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_3_2 = pd.read_csv("./data/3_2_df.csv")
df_3_2.set_index('No', inplace=True)
df_3_2.sort_values(by=['Driver', 'Stops'])
df_3_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

italy_df = italy_df.join(df_3_2[['Stops', 'Total']], on='No')
italy_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)

df_3_3 = pd.read_csv("./data/3_3_df.csv")
df_3_3.set_index('No', inplace=True)

italy_df = italy_df.join(df_3_3[['Pos']], on='No')
italy_df.rename(columns={"Pos": "Starting Grid Pos"}, inplace=True)

df_3_4 = pd.read_csv("./data/3_4_df.csv")
df_3_4.set_index('No', inplace=True)

italy_df = italy_df.join(df_3_4[['Pos', 'Laps', 'Time/Retired', 'PTS']], on='No')
italy_df.rename(columns={"Pos": "Final Sprint Postition", "Laps": "Sprint Laps", "Time/Retired": "Sprint Time/Retired", "PTS": "Sprint PTS"}, inplace=True)

df_3_5 = pd.read_csv("./data/3_5_df.csv")
df_3_5.set_index('No', inplace=True)

italy_df = italy_df.join(df_3_5[['Pos', 'Time']], on='No')
italy_df.rename(columns={"Pos": "Starting Sprint Postition", "Time": "Sprint Grid Time"}, inplace=True)

df_3_6 = pd.read_csv("./data/3_6_df.csv")
df_3_6.set_index('No', inplace=True)

italy_df = italy_df.join(df_3_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
italy_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_3_7 = pd.read_csv("./data/3_7_df.csv")
df_3_7.set_index('No', inplace=True)

italy_df = italy_df.join(df_3_7[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
italy_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)

df_3_8 = pd.read_csv("./data/3_8_df.csv")
df_3_8.set_index('No', inplace=True)

italy_df = italy_df.join(df_3_8[['Pos', 'Time', 'Gap', 'Laps']], on='No')
italy_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

italy_df['Race'] = 'Emilia Romagna'

italy_df.head(5)
# Out:
#    Final Race Position            Driver Name                   Car  \
# No
# 1                    1   Max  Verstappen  VER  Red Bull Racing RBPT
# 11                   2     Sergio  Perez  PER  Red Bull Racing RBPT
# 4                    3     Lando  Norris  NOR      McLaren Mercedes
# 63                   4   George  Russell  RUS              Mercedes
# 77                   5  Valtteri  Bottas  BOT    Alfa Romeo Ferrari
#
#     Race Laps    Race Time  Race Points  Fastest Lap No Time of day  \
# No
# 1          63  1:32:07.986           26            55.0    16:24:32
# 11         63     +16.527s           18            52.0    16:20:46
# 4          63     +34.834s           15            61.0    16:33:03
# 63         63     +42.506s           12            57.0    16:27:45
# 77         63     +43.181s           10            43.0    16:08:51
#
#    Fastest Lap Time  Avg Speed  Stops Total Pit Time  Starting Grid Pos  \
# No
# ...

# %%
italy_df_copy = italy_df.copy()
italy_df_copy.head(5)
# Out:
#    Final Race Position            Driver Name                   Car  \
# No
# 1                    1   Max  Verstappen  VER  Red Bull Racing RBPT
# 11                   2     Sergio  Perez  PER  Red Bull Racing RBPT
# 4                    3     Lando  Norris  NOR      McLaren Mercedes
# 63                   4   George  Russell  RUS              Mercedes
# 77                   5  Valtteri  Bottas  BOT    Alfa Romeo Ferrari
#
#     Race Laps    Race Time  Race Points  Fastest Lap No Time of day  \
# No
# 1          63  1:32:07.986           26            55.0    16:24:32
# 11         63     +16.527s           18            52.0    16:20:46
# 4          63     +34.834s           15            61.0    16:33:03
# 63         63     +42.506s           12            57.0    16:27:45
# 77         63     +43.181s           10            43.0    16:08:51
#
#    Fastest Lap Time  Avg Speed  Stops Total Pit Time  Starting Grid Pos  \
# No
# ...

# %%
sprint_time = italy_df_copy['Sprint Time/Retired']
sprint_time = sprint_time.map(lambda x: x.lstrip('+-'))
sprint_time = sprint_time.map(lambda x: x.rstrip('s'))
#sprint_time

# %%
sprint_time_copy = sprint_time.copy()
for count, race in enumerate(sprint_time):
    # Race time is always first index
    if (count == 0):
#        print(f"COUNT: {count} | VALUE: {race} | IN COUNT 0")
        end_time = race
        my_list = end_time.split(':')
        time_f = timedelta(minutes=int(my_list[0]), seconds=float(my_list[1])).total_seconds()
        sprint_time_copy.iloc[count] = time_f
    # Use regex to check if a float value exists
    elif re.match(r'^-?\d+(?:\.\d+)$', race) is not None:
        print(f"COUNT: {count} | VALUE: {race} | IN INSTANCE")
        sprint_time_copy.iloc[count] = (time_f + float(race))
    # Anything else such as DNF, DSQ will get 999999
    else:
#        print(f"COUNT: {count} | VALUE: {race} | IN ELSE")
        sprint_time_copy.iloc[count] = 999999
# Out:
# COUNT: 1 | VALUE: 4.721 | IN INSTANCE
# COUNT: 2 | VALUE: 24.561 | IN INSTANCE
# COUNT: 3 | VALUE: 36.284 | IN INSTANCE
# COUNT: 4 | VALUE: 28.133 | IN INSTANCE
# COUNT: 5 | VALUE: 2.975 | IN INSTANCE
# COUNT: 6 | VALUE: 38.298 | IN INSTANCE
# COUNT: 7 | VALUE: 40.177 | IN INSTANCE
# COUNT: 8 | VALUE: 30.712 | IN INSTANCE
# COUNT: 9 | VALUE: 42.910 | IN INSTANCE
# COUNT: 10 | VALUE: 48.871 | IN INSTANCE
# COUNT: 11 | VALUE: 43.794 | IN INSTANCE
# COUNT: 12 | VALUE: 41.459 | IN INSTANCE
# COUNT: 13 | VALUE: 43.517 | IN INSTANCE
# COUNT: 15 | VALUE: 52.017 | IN INSTANCE
# COUNT: 16 | VALUE: 33.773 | IN INSTANCE
# COUNT: 17 | VALUE: 27.740 | IN INSTANCE
# COUNT: 18 | VALUE: 32.278 | IN INSTANCE
# COUNT: 19 | VALUE: 17.578 | IN INSTANCE

# %%
italy_df_copy['Sprint Time/Retired'] = sprint_time_copy
italy_df_copy
# Out:
#    Final Race Position             Driver Name                           Car  \
# No
# 1                    1    Max  Verstappen  VER          Red Bull Racing RBPT
# 11                   2      Sergio  Perez  PER          Red Bull Racing RBPT
# 4                    3      Lando  Norris  NOR              McLaren Mercedes
# 63                   4    George  Russell  RUS                      Mercedes
# 77                   5   Valtteri  Bottas  BOT            Alfa Romeo Ferrari
# 16                   6   Charles  Leclerc  LEC                       Ferrari
# 22                   7      Yuki  Tsunoda  TSU               AlphaTauri RBPT
# 5                    8  Sebastian  Vettel  VET  Aston Martin Aramco Mercedes
# 20                   9   Kevin  Magnussen  MAG                  Haas Ferrari
# 18                  10      Lance  Stroll  STR  Aston Martin Aramco Mercedes
# 23                  11   Alexander  Albon  ALB             Williams Mercedes
# ...

# %%
# Miami Race 2022
# [Pos, No, Driver, Car, Race Laps, Time/Retired, Race PTS], [Fastest Lap, Time of day, Fastest Lap Time, Avg Speed], [Total Stops], [Starting Grid Position, Final Qualifying Time], [Q1 Time, Q2 Time, Q3 Time, Qualifying Laps]
miami_df = pd.DataFrame()

# Import race result data
df_4_0 = pd.read_csv("./data/4_0_df.csv")

miami_df['Final Race Position'] = df_4_0['Pos']
miami_df['No'] = df_4_0['No']
miami_df['Driver Name'] = df_4_0['Driver']
miami_df['Car'] = df_4_0['Car']
miami_df['Race Laps'] = df_4_0['Laps']
miami_df['Race Time'] = df_4_0['Time/Retired']
miami_df['Race Points'] = df_4_0['PTS']
miami_df.set_index('No', inplace=True)

df_4_1 = pd.read_csv("./data/4_1_df.csv")
df_4_1.set_index('No', inplace=True)

miami_df = miami_df.join(df_4_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
miami_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_4_2 = pd.read_csv("./data/4_2_df.csv")
df_4_2.set_index('No', inplace=True)
df_4_2.sort_values(by=['Driver', 'Stops'])
df_4_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

miami_df = miami_df.join(df_4_2[['Stops', 'Total']], on='No')
miami_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
miami_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)

df_4_3 = pd.read_csv("./data/4_3_df.csv")
df_4_3.set_index('No', inplace=True)

miami_df = miami_df.join(df_4_3[['Pos', 'Time']], on='No')
miami_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)


df_4_4 = pd.read_csv("./data/4_4_df.csv")
df_4_4.set_index('No', inplace=True)

miami_df = miami_df.join(df_4_4[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
miami_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)


df_4_5 = pd.read_csv("./data/4_5_df.csv")
df_4_5.set_index('No', inplace=True)

miami_df = miami_df.join(df_4_5[['Pos', 'Time', 'Gap', 'Laps']], on='No')
miami_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)


df_4_6 = pd.read_csv("./data/4_6_df.csv")
df_4_6.set_index('No', inplace=True)

miami_df = miami_df.join(df_4_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
miami_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_4_7 = pd.read_csv("./data/4_7_df.csv")
df_4_7.set_index('No', inplace=True)

miami_df = miami_df.join(df_4_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
miami_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

miami_df['Race'] = 'Miami'

miami_df.head(5)
# Out:
#    Final Race Position            Driver Name                   Car  \
# No
# 1                    1   Max  Verstappen  VER  Red Bull Racing RBPT
# 16                   2  Charles  Leclerc  LEC               Ferrari
# 55                   3     Carlos  Sainz  SAI               Ferrari
# 11                   4     Sergio  Perez  PER  Red Bull Racing RBPT
# 63                   5   George  Russell  RUS              Mercedes
#
#     Race Laps    Race Time  Race Points  Fastest Lap No Time of day  \
# No
# 1          57  1:34:24.258           26              54    17:03:04
# 16         57      +3.786s           18              53    17:01:34
# 55         57      +8.229s           15              56    17:06:15
# 11         57     +10.638s           12              54    17:03:13
# 63         57     +18.582s           10              56    17:06:25
#
#    Fastest Lap Time  Avg Speed  Stops  Total Pit Time  Starting Grid Pos  \
# No
# ...

# %%
# Spain Race 2022
# [Pos, No, Driver, Car, Race Laps, Time/Retired, Race PTS], [Fastest Lap, Time of day, Fastest Lap Time, Avg Speed], [Total Stops], [Starting Grid Position, Final Qualifying Time], [Q1 Time, Q2 Time, Q3 Time, Qualifying Laps]
spain_df = pd.DataFrame()

# Import race result data
df_5_0 = pd.read_csv("./data/5_0_df.csv")

spain_df['Final Race Position'] = df_5_0['Pos']
spain_df['No'] = df_5_0['No']
spain_df['Driver Name'] = df_5_0['Driver']
spain_df['Car'] = df_5_0['Car']
spain_df['Race Laps'] = df_5_0['Laps']
spain_df['Race Time'] = df_5_0['Time/Retired']
spain_df['Race Points'] = df_5_0['PTS']
spain_df.set_index('No', inplace=True)

df_5_1 = pd.read_csv("./data/5_1_df.csv")
df_5_1.set_index('No', inplace=True)

spain_df = spain_df.join(df_5_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
spain_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_5_2 = pd.read_csv("./data/5_2_df.csv")
df_5_2.set_index('No', inplace=True)
df_5_2.sort_values(by=['Driver', 'Stops'])
df_5_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

spain_df = spain_df.join(df_5_2[['Stops', 'Total']], on='No')
spain_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
spain_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)

df_5_3 = pd.read_csv("./data/5_3_df.csv")
df_5_3.set_index('No', inplace=True)

spain_df = spain_df.join(df_5_3[['Pos', 'Time']], on='No')
spain_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)


df_5_4 = pd.read_csv("./data/5_4_df.csv")
df_5_4.set_index('No', inplace=True)

spain_df = spain_df.join(df_5_4[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
spain_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)


df_5_5 = pd.read_csv("./data/5_5_df.csv")
df_5_5.set_index('No', inplace=True)

spain_df = spain_df.join(df_5_5[['Pos', 'Time', 'Gap', 'Laps']], on='No')
spain_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)


df_5_6 = pd.read_csv("./data/5_6_df.csv")
df_5_6.set_index('No', inplace=True)

spain_df = spain_df.join(df_5_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
spain_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_5_7 = pd.read_csv("./data/5_7_df.csv")
df_5_7.set_index('No', inplace=True)

spain_df = spain_df.join(df_5_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
spain_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

spain_df['Race'] = 'Spain'

spain_df.head(5)
# Out:
#    Final Race Position           Driver Name                   Car  Race Laps  \
# No
# 1                    1  Max  Verstappen  VER  Red Bull Racing RBPT         66
# 11                   2    Sergio  Perez  PER  Red Bull Racing RBPT         66
# 63                   3  George  Russell  RUS              Mercedes         66
# 55                   4    Carlos  Sainz  SAI               Ferrari         66
# 44                   5  Lewis  Hamilton  HAM              Mercedes         66
#
#       Race Time  Race Points  Fastest Lap No Time of day Fastest Lap Time  \
# No
# 1   1:37:20.475           25              46    16:11:38         1:25.456
# 11     +13.072s           19              55    16:25:00         1:24.108
# 63     +32.927s           15              53    16:22:13         1:24.636
# 55     +45.208s           12              49    16:16:37         1:25.985
# 44     +54.534s           10              51    16:19:36         1:24.253
#
# ...

# %%
# Monaco Race 2022
# [Pos, No, Driver, Car, Race Laps, Time/Retired, Race PTS], [Fastest Lap, Time of day, Fastest Lap Time, Avg Speed], [Total Stops], [Starting Grid Position, Final Qualifying Time], [Q1 Time, Q2 Time, Q3 Time, Qualifying Laps]
monaco_df = pd.DataFrame()

# Import race result data
df_6_0 = pd.read_csv("./data/6_0_df.csv")

monaco_df['Final Race Position'] = df_6_0['Pos']
monaco_df['No'] = df_6_0['No']
monaco_df['Driver Name'] = df_6_0['Driver']
monaco_df['Car'] = df_6_0['Car']
monaco_df['Race Laps'] = df_6_0['Laps']
monaco_df['Race Time'] = df_6_0['Time/Retired']
monaco_df['Race Points'] = df_6_0['PTS']
monaco_df.set_index('No', inplace=True)

df_6_1 = pd.read_csv("./data/6_1_df.csv")
df_6_1.set_index('No', inplace=True)

monaco_df = monaco_df.join(df_6_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
monaco_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_6_2 = pd.read_csv("./data/6_2_df.csv")
df_6_2.set_index('No', inplace=True)
df_6_2.sort_values(by=['Driver', 'Stops'])
df_6_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

monaco_df = monaco_df.join(df_6_2[['Stops', 'Total']], on='No')
monaco_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
monaco_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)

df_6_3 = pd.read_csv("./data/6_3_df.csv")
df_6_3.set_index('No', inplace=True)

monaco_df = monaco_df.join(df_6_3[['Pos', 'Time']], on='No')
monaco_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)


df_6_4 = pd.read_csv("./data/6_4_df.csv")
df_6_4.set_index('No', inplace=True)

monaco_df = monaco_df.join(df_6_4[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
monaco_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)


df_6_5 = pd.read_csv("./data/6_5_df.csv")
df_6_5.set_index('No', inplace=True)

monaco_df = monaco_df.join(df_6_5[['Pos', 'Time', 'Gap', 'Laps']], on='No')
monaco_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)


df_6_6 = pd.read_csv("./data/6_6_df.csv")
df_6_6.set_index('No', inplace=True)

monaco_df = monaco_df.join(df_6_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
monaco_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_6_7 = pd.read_csv("./data/6_7_df.csv")
df_6_7.set_index('No', inplace=True)

monaco_df = monaco_df.join(df_6_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
monaco_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

monaco_df['Race'] = 'Monaco'

monaco_df.head(5)
# Out:
#    Final Race Position            Driver Name                   Car  \
# No
# 11                   1     Sergio  Perez  PER  Red Bull Racing RBPT
# 55                   2     Carlos  Sainz  SAI               Ferrari
# 1                    3   Max  Verstappen  VER  Red Bull Racing RBPT
# 16                   4  Charles  Leclerc  LEC               Ferrari
# 63                   5   George  Russell  RUS              Mercedes
#
#     Race Laps    Race Time  Race Points  Fastest Lap No Time of day  \
# No
# 11         64  1:56:30.265           25              46    17:38:05
# 55         64      +1.154s           18              47    17:39:24
# 1          64      +1.491s           15              47    17:39:26
# 16         64      +2.922s           12              46    17:38:11
# 63         64     +11.968s           10              42    17:33:07
#
#    Fastest Lap Time  Avg Speed  Stops Total Pit Time  Starting Grid Pos  \
# No
# ...

# %%
# Azerbaijan Race 2022
# [Pos, No, Driver, Car, Race Laps, Time/Retired, Race PTS], [Fastest Lap, Time of day, Fastest Lap Time, Avg Speed], [Total Stops], [Starting Grid Position, Final Qualifying Time], [Q1 Time, Q2 Time, Q3 Time, Qualifying Laps]
azerbaijan_df = pd.DataFrame()

# Import race result data
df_7_0 = pd.read_csv("./data/7_0_df.csv")

azerbaijan_df['Final Race Position'] = df_7_0['Pos']
azerbaijan_df['No'] = df_7_0['No']
azerbaijan_df['Driver Name'] = df_7_0['Driver']
azerbaijan_df['Car'] = df_7_0['Car']
azerbaijan_df['Race Laps'] = df_7_0['Laps']
azerbaijan_df['Race Time'] = df_7_0['Time/Retired']
azerbaijan_df['Race Points'] = df_7_0['PTS']
azerbaijan_df.set_index('No', inplace=True)

df_7_1 = pd.read_csv("./data/7_1_df.csv")
df_7_1.set_index('No', inplace=True)

azerbaijan_df = azerbaijan_df.join(df_7_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
azerbaijan_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_7_2 = pd.read_csv("./data/7_2_df.csv")
df_7_2.set_index('No', inplace=True)
df_7_2.sort_values(by=['Driver', 'Stops'])
df_7_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

azerbaijan_df = azerbaijan_df.join(df_7_2[['Stops', 'Total']], on='No')
azerbaijan_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
azerbaijan_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)

df_7_3 = pd.read_csv("./data/7_3_df.csv")
df_7_3.set_index('No', inplace=True)

azerbaijan_df = azerbaijan_df.join(df_7_3[['Pos', 'Time']], on='No')
azerbaijan_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)


df_7_4 = pd.read_csv("./data/7_4_df.csv")
df_7_4.set_index('No', inplace=True)

azerbaijan_df = azerbaijan_df.join(df_7_4[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
azerbaijan_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)


df_7_5 = pd.read_csv("./data/7_5_df.csv")
df_7_5.set_index('No', inplace=True)

azerbaijan_df = azerbaijan_df.join(df_7_5[['Pos', 'Time', 'Gap', 'Laps']], on='No')
azerbaijan_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)


df_7_6 = pd.read_csv("./data/7_6_df.csv")
df_7_6.set_index('No', inplace=True)

azerbaijan_df = azerbaijan_df.join(df_7_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
azerbaijan_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_7_7 = pd.read_csv("./data/7_7_df.csv")
df_7_7.set_index('No', inplace=True)

azerbaijan_df = azerbaijan_df.join(df_7_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
azerbaijan_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

azerbaijan_df['Race'] = 'Azerbaijan'

azerbaijan_df.head(5)
# Out:
#    Final Race Position           Driver Name                   Car  Race Laps  \
# No
# 1                    1  Max  Verstappen  VER  Red Bull Racing RBPT         51
# 11                   2    Sergio  Perez  PER  Red Bull Racing RBPT         51
# 63                   3  George  Russell  RUS              Mercedes         51
# 44                   4  Lewis  Hamilton  HAM              Mercedes         51
# 10                   5    Pierre  Gasly  GAS       AlphaTauri RBPT         51
#
#       Race Time  Race Points  Fastest Lap No Time of day Fastest Lap Time  \
# No
# 1   1:34:05.941           25              50    16:36:14         1:46.050
# 11     +20.823s           19              36    16:11:32         1:46.046
# 63     +45.995s           15              42    16:22:38         1:47.177
# 44     +71.679s           12              39    16:17:36         1:47.044
# 10     +77.299s           10              39    16:17:30         1:48.519
#
# ...

# %%
# Canada Race 2022
# [Pos, No, Driver, Car, Race Laps, Time/Retired, Race PTS], [Fastest Lap, Time of day, Fastest Lap Time, Avg Speed], [Total Stops], [Starting Grid Position, Final Qualifying Time], [Q1 Time, Q2 Time, Q3 Time, Qualifying Laps]
canada_df = pd.DataFrame()

# Import race result data
df_8_0 = pd.read_csv("./data/8_0_df.csv")

canada_df['Final Race Position'] = df_8_0['Pos']
canada_df['No'] = df_8_0['No']
canada_df['Driver Name'] = df_8_0['Driver']
canada_df['Car'] = df_8_0['Car']
canada_df['Race Laps'] = df_8_0['Laps']
canada_df['Race Time'] = df_8_0['Time/Retired']
canada_df['Race Points'] = df_8_0['PTS']
canada_df.set_index('No', inplace=True)

df_8_1 = pd.read_csv("./data/8_1_df.csv")
df_8_1.set_index('No', inplace=True)

canada_df = canada_df.join(df_8_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
canada_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_8_2 = pd.read_csv("./data/8_2_df.csv")
df_8_2.set_index('No', inplace=True)
df_8_2.sort_values(by=['Driver', 'Stops'])
df_8_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

canada_df = canada_df.join(df_8_2[['Stops', 'Total']], on='No')
canada_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
canada_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)

df_8_3 = pd.read_csv("./data/8_3_df.csv")
df_8_3.set_index('No', inplace=True)

canada_df = canada_df.join(df_8_3[['Pos', 'Time']], on='No')
canada_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)


df_8_4 = pd.read_csv("./data/8_4_df.csv")
df_8_4.set_index('No', inplace=True)

canada_df = canada_df.join(df_8_4[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
canada_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)


df_8_5 = pd.read_csv("./data/8_5_df.csv")
df_8_5.set_index('No', inplace=True)

canada_df = canada_df.join(df_8_5[['Pos', 'Time', 'Gap', 'Laps']], on='No')
canada_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)


df_8_6 = pd.read_csv("./data/8_6_df.csv")
df_8_6.set_index('No', inplace=True)

canada_df = canada_df.join(df_8_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
canada_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_8_7 = pd.read_csv("./data/8_7_df.csv")
df_8_7.set_index('No', inplace=True)

canada_df = canada_df.join(df_8_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
canada_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

canada_df['Race'] = 'Canada'

canada_df.head(5)
# Out:
#    Final Race Position            Driver Name                   Car  \
# No
# 1                    1   Max  Verstappen  VER  Red Bull Racing RBPT
# 55                   2     Carlos  Sainz  SAI               Ferrari
# 44                   3   Lewis  Hamilton  HAM              Mercedes
# 63                   4   George  Russell  RUS              Mercedes
# 16                   5  Charles  Leclerc  LEC               Ferrari
#
#     Race Laps    Race Time  Race Points  Fastest Lap No Time of day  \
# No
# 1          70  1:36:21.757           25              64    15:31:59
# 55         70      +0.993s           19              63    15:30:43
# 44         70      +7.006s           15              69    15:38:25
# 63         70     +12.313s           12              63    15:30:51
# 16         70     +15.168s           10              62    15:29:37
#
#    Fastest Lap Time  Avg Speed  Stops Total Pit Time  Starting Grid Pos  \
# No
# ...

# %%
# Great Britain Race 2022
# [Pos, No, Driver, Car, Race Laps, Time/Retired, Race PTS], [Fastest Lap, Time of day, Fastest Lap Time, Avg Speed], [Total Stops], [Starting Grid Position, Final Qualifying Time], [Q1 Time, Q2 Time, Q3 Time, Qualifying Laps]
great_britain_df = pd.DataFrame()

# Import race result data
df_9_0 = pd.read_csv("./data/9_0_df.csv")

great_britain_df['Final Race Position'] = df_9_0['Pos']
great_britain_df['No'] = df_9_0['No']
great_britain_df['Driver Name'] = df_9_0['Driver']
great_britain_df['Car'] = df_9_0['Car']
great_britain_df['Race Laps'] = df_9_0['Laps']
great_britain_df['Race Time'] = df_9_0['Time/Retired']
great_britain_df['Race Points'] = df_9_0['PTS']
great_britain_df.set_index('No', inplace=True)

df_9_1 = pd.read_csv("./data/9_1_df.csv")
df_9_1.set_index('No', inplace=True)

great_britain_df = great_britain_df.join(df_9_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
great_britain_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_9_2 = pd.read_csv("./data/9_2_df.csv")
df_9_2.set_index('No', inplace=True)
df_9_2.sort_values(by=['Driver', 'Stops'])
df_9_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

great_britain_df = great_britain_df.join(df_9_2[['Stops', 'Total']], on='No')
great_britain_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
great_britain_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)

df_9_3 = pd.read_csv("./data/9_3_df.csv")
df_9_3.set_index('No', inplace=True)

great_britain_df = great_britain_df.join(df_9_3[['Pos', 'Time']], on='No')
great_britain_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)


df_9_4 = pd.read_csv("./data/9_4_df.csv")
df_9_4.set_index('No', inplace=True)

great_britain_df = great_britain_df.join(df_9_4[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
great_britain_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)


df_9_5 = pd.read_csv("./data/9_5_df.csv")
df_9_5.set_index('No', inplace=True)

great_britain_df = great_britain_df.join(df_9_5[['Pos', 'Time', 'Gap', 'Laps']], on='No')
great_britain_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)


df_9_6 = pd.read_csv("./data/9_6_df.csv")
df_9_6.set_index('No', inplace=True)

great_britain_df = great_britain_df.join(df_9_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
great_britain_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_9_7 = pd.read_csv("./data/9_7_df.csv")
df_9_7.set_index('No', inplace=True)

great_britain_df = great_britain_df.join(df_9_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
great_britain_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

great_britain_df['Race'] = 'Great Britain'

great_britain_df.head(5)
# Out:
#    Final Race Position            Driver Name                   Car  \
# No
# 55                   1     Carlos  Sainz  SAI               Ferrari
# 11                   2     Sergio  Perez  PER  Red Bull Racing RBPT
# 44                   3   Lewis  Hamilton  HAM              Mercedes
# 16                   4  Charles  Leclerc  LEC               Ferrari
# 14                   5  Fernando  Alonso  ALO        Alpine Renault
#
#     Race Laps    Race Time  Race Points  Fastest Lap No Time of day  \
# No
# 55         52  2:17:50.311           25            44.0    17:08:55
# 11         52      +3.779s           18            47.0    17:13:33
# 44         52      +6.225s           16            52.0    17:21:12
# 16         52      +8.546s           12            52.0    17:21:14
# 14         52      +9.571s           10            47.0    17:13:35
#
#    Fastest Lap Time  Avg Speed  Stops Total Pit Time  Starting Grid Pos  \
# No
# ...

# %%
# Austria Race 2022

austria_df = pd.DataFrame()

df_10_0 = pd.read_csv("./data/10_0_df.csv")

austria_df['Final Race Position'] = df_10_0['Pos']
austria_df['No'] = df_10_0['No']
austria_df['Driver Name'] = df_10_0['Driver']
austria_df['Car'] = df_10_0['Car']
austria_df['Race Laps'] = df_10_0['Laps']
austria_df['Race Time'] = df_10_0['Time/Retired']
austria_df['Race Points'] = df_10_0['PTS']
austria_df.set_index('No', inplace=True)

df_10_1 = pd.read_csv("./data/10_1_df.csv")
df_10_1.set_index('No', inplace=True)

austria_df = austria_df.join(df_10_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
austria_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_10_2 = pd.read_csv("./data/10_2_df.csv")
df_10_2.set_index('No', inplace=True)
df_10_2.sort_values(by=['Driver', 'Stops'])
df_10_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

austria_df = austria_df.join(df_10_2[['Stops', 'Total']], on='No')
austria_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)

df_10_3 = pd.read_csv("./data/10_3_df.csv")
df_10_3.set_index('No', inplace=True)

austria_df = austria_df.join(df_10_3[['Pos']], on='No')
austria_df.rename(columns={"Pos": "Starting Grid Pos"}, inplace=True)

df_10_4 = pd.read_csv("./data/10_4_df.csv")
df_10_4.set_index('No', inplace=True)

austria_df = austria_df.join(df_10_4[['Pos', 'Laps', 'Time/Retired', 'PTS']], on='No')
austria_df.rename(columns={"Pos": "Final Sprint Postition", "Laps": "Sprint Laps", "Time/Retired": "Sprint Time/Retired", "PTS": "Sprint PTS"}, inplace=True)

df_10_5 = pd.read_csv("./data/10_5_df.csv")
df_10_5.set_index('No', inplace=True)

austria_df = austria_df.join(df_10_5[['Pos', 'Time']], on='No')
austria_df.rename(columns={"Pos": "Starting Sprint Postition", "Time": "Sprint Grid Time"}, inplace=True)

df_10_6 = pd.read_csv("./data/10_6_df.csv")
df_10_6.set_index('No', inplace=True)

austria_df = austria_df.join(df_10_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
austria_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_10_7 = pd.read_csv("./data/10_7_df.csv")
df_10_7.set_index('No', inplace=True)

austria_df = austria_df.join(df_10_7[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
austria_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)

df_10_8 = pd.read_csv("./data/10_8_df.csv")
df_10_8.set_index('No', inplace=True)

austria_df = austria_df.join(df_10_8[['Pos', 'Time', 'Gap', 'Laps']], on='No')
austria_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

austria_df['Race'] = 'Austria'

austria_df.head(5)
# Out:
#    Final Race Position            Driver Name                   Car  \
# No
# 16                   1  Charles  Leclerc  LEC               Ferrari
# 1                    2   Max  Verstappen  VER  Red Bull Racing RBPT
# 44                   3   Lewis  Hamilton  HAM              Mercedes
# 63                   4   George  Russell  RUS              Mercedes
# 31                   5     Esteban  Ocon  OCO        Alpine Renault
#
#     Race Laps    Race Time  Race Points  Fastest Lap No Time of day  \
# No
# 16         71  1:24:24.312           25              62    16:17:19
# 1          71      +1.532s           19              62    16:17:22
# 44         71     +41.217s           15              63    16:19:02
# 63         71     +58.972s           12              61    16:17:00
# 31         71     +68.436s           10              62    16:18:10
#
#    Fastest Lap Time  Avg Speed  Stops Total Pit Time  Starting Grid Pos  \
# No
# ...

# %%
austria_df_copy=austria_df.copy()

# %%
sprint_time = austria_df_copy['Sprint Time/Retired']
sprint_time = sprint_time.map(lambda x: x.lstrip('+-'))
sprint_time = sprint_time.map(lambda x: x.rstrip('s'))
#sprint_time

# %%
sprint_time_copy = sprint_time.copy()
for count, race in enumerate(sprint_time):
    # Race time is always first index
    if (count == 1):
#        print(f"COUNT: {count} | VALUE: {race} | IN COUNT 0")
        end_time = race
        my_list = end_time.split(':')
        time_f = timedelta(minutes=int(my_list[0]), seconds=float(my_list[1])).total_seconds()
        sprint_time_copy.iloc[count] = time_f
    # Use regex to check if a float value exists
    elif re.match(r'^-?\d+(?:\.\d+)$', race) is not None:
#        print(f"COUNT: {count} | VALUE: {race} | IN INSTANCE")
        sprint_time_copy.iloc[count] = (time_f + float(race))
    # Anything else such as DNF, DSQ will get 999999
    else:
#        print(f"COUNT: {count} | VALUE: {race} | IN ELSE")
        sprint_time_copy.iloc[count] = 999999

# %%
austria_df_copy['Sprint Time/Retired'] = sprint_time_copy
austria_df_copy
# Out:
#    Final Race Position             Driver Name                           Car  \
# No
# 16                   1   Charles  Leclerc  LEC                       Ferrari
# 1                    2    Max  Verstappen  VER          Red Bull Racing RBPT
# 44                   3    Lewis  Hamilton  HAM                      Mercedes
# 63                   4    George  Russell  RUS                      Mercedes
# 31                   5      Esteban  Ocon  OCO                Alpine Renault
# 47                   6   Mick  Schumacher  MSC                  Haas Ferrari
# 4                    7      Lando  Norris  NOR              McLaren Mercedes
# 20                   8   Kevin  Magnussen  MAG                  Haas Ferrari
# 3                    9  Daniel  Ricciardo  RIC              McLaren Mercedes
# 14                  10   Fernando  Alonso  ALO                Alpine Renault
# 77                  11   Valtteri  Bottas  BOT            Alfa Romeo Ferrari
# ...

# %%
# France Race 2022
# [Pos, No, Driver, Car, Race Laps, Time/Retired, Race PTS], [Fastest Lap, Time of day, Fastest Lap Time, Avg Speed], [Total Stops], [Starting Grid Position, Final Qualifying Time], [Q1 Time, Q2 Time, Q3 Time, Qualifying Laps]
france_df = pd.DataFrame()

# Import race result data
df_11_0 = pd.read_csv("./data/11_0_df.csv")

france_df['Final Race Position'] = df_11_0['Pos']
france_df['No'] = df_11_0['No']
france_df['Driver Name'] = df_11_0['Driver']
france_df['Car'] = df_11_0['Car']
france_df['Race Laps'] = df_11_0['Laps']
france_df['Race Time'] = df_11_0['Time/Retired']
france_df['Race Points'] = df_11_0['PTS']
france_df.set_index('No', inplace=True)

df_11_1 = pd.read_csv("./data/11_1_df.csv")
df_11_1.set_index('No', inplace=True)

france_df = france_df.join(df_11_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
france_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_11_2 = pd.read_csv("./data/11_2_df.csv")
df_11_2.set_index('No', inplace=True)
df_11_2.sort_values(by=['Driver', 'Stops'])
df_11_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

france_df = france_df.join(df_11_2[['Stops', 'Total']], on='No')
france_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
france_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)

df_11_3 = pd.read_csv("./data/11_3_df.csv")
df_11_3.set_index('No', inplace=True)

france_df = france_df.join(df_11_3[['Pos', 'Time']], on='No')
france_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)


df_11_4 = pd.read_csv("./data/11_4_df.csv")
df_11_4.set_index('No', inplace=True)

france_df = france_df.join(df_11_4[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
france_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)


df_11_5 = pd.read_csv("./data/11_5_df.csv")
df_11_5.set_index('No', inplace=True)

france_df = france_df.join(df_11_5[['Pos', 'Time', 'Gap', 'Laps']], on='No')
france_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)


df_11_6 = pd.read_csv("./data/11_6_df.csv")
df_11_6.set_index('No', inplace=True)

france_df = france_df.join(df_11_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
france_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_11_7 = pd.read_csv("./data/11_7_df.csv")
df_11_7.set_index('No', inplace=True)

france_df = france_df.join(df_11_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
france_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

france_df['Race'] = 'France'

france_df.head(5)
# Out:
#    Final Race Position           Driver Name                   Car  Race Laps  \
# No
# 1                    1  Max  Verstappen  VER  Red Bull Racing RBPT         53
# 44                   2  Lewis  Hamilton  HAM              Mercedes         53
# 63                   3  George  Russell  RUS              Mercedes         53
# 11                   4    Sergio  Perez  PER  Red Bull Racing RBPT         53
# 55                   5    Carlos  Sainz  SAI               Ferrari         53
#
#       Race Time  Race Points  Fastest Lap No Time of day Fastest Lap Time  \
# No
# 1   1:30:02.112           25              30    15:55:33         1:37.491
# 44     +10.587s           18              30    15:55:37         1:37.668
# 63     +16.495s           15              51    16:30:42         1:37.548
# 11     +17.310s           12              45    16:20:19         1:37.780
# 55     +28.872s           11              51    16:30:58         1:35.781
#
# ...

# %%
# Hungary Race 2022
# [Pos, No, Driver, Car, Race Laps, Time/Retired, Race PTS], [Fastest Lap, Time of day, Fastest Lap Time, Avg Speed], [Total Stops], [Starting Grid Position, Final Qualifying Time], [Q1 Time, Q2 Time, Q3 Time, Qualifying Laps]
hungary_df = pd.DataFrame()

# Import race result data
df_12_0 = pd.read_csv("./data/12_0_df.csv")

hungary_df['Final Race Position'] = df_12_0['Pos']
hungary_df['No'] = df_12_0['No']
hungary_df['Driver Name'] = df_12_0['Driver']
hungary_df['Car'] = df_12_0['Car']
hungary_df['Race Laps'] = df_12_0['Laps']
hungary_df['Race Time'] = df_12_0['Time/Retired']
hungary_df['Race Points'] = df_12_0['PTS']
hungary_df.set_index('No', inplace=True)

df_12_1 = pd.read_csv("./data/12_1_df.csv")
df_12_1.set_index('No', inplace=True)

hungary_df = hungary_df.join(df_12_1[['Lap', 'Time of day', 'Time', 'Avg Speed']], on='No')
hungary_df.rename(columns={"Lap": "Fastest Lap No", "Time": "Fastest Lap Time"}, inplace=True)

df_12_2 = pd.read_csv("./data/12_2_df.csv")
df_12_2.set_index('No', inplace=True)
df_12_2.sort_values(by=['Driver', 'Stops'])
df_12_2.drop_duplicates(subset=['Driver'], keep='last', inplace=True)

hungary_df = hungary_df.join(df_12_2[['Stops', 'Total']], on='No')
hungary_df.rename(columns={"Total": "Total Pit Time"}, inplace=True)
hungary_df.rename(columns={"Time": "Fastest Lap Time"}, inplace=True)

df_12_3 = pd.read_csv("./data/12_3_df.csv")
df_12_3.set_index('No', inplace=True)

hungary_df = hungary_df.join(df_12_3[['Pos', 'Time']], on='No')
hungary_df.rename(columns={"Lap": "Fastest Lap No", "Total": "Total Pit Time", "Pos": "Starting Grid Pos", "Time": "Starting Grid Quali Time"}, inplace=True)


df_12_4 = pd.read_csv("./data/12_4_df.csv")
df_12_4.set_index('No', inplace=True)

hungary_df = hungary_df.join(df_12_4[['Pos', 'Q1', 'Q2', 'Q3', 'Laps']], on='No')
hungary_df.rename(columns={"Pos": "Qualifying Postition", "Laps": "Qualifying Laps"}, inplace=True)


df_12_5 = pd.read_csv("./data/12_5_df.csv")
df_12_5.set_index('No', inplace=True)

hungary_df = hungary_df.join(df_12_5[['Pos', 'Time', 'Gap', 'Laps']], on='No')
hungary_df.rename(columns={"Pos": "P3 Postition", "Time": "P3 Time", "Gap": "P3 Gap", "Laps": "P3 Laps"}, inplace=True)


df_12_6 = pd.read_csv("./data/12_6_df.csv")
df_12_6.set_index('No', inplace=True)

hungary_df = hungary_df.join(df_12_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
hungary_df.rename(columns={"Pos": "P2 Postition", "Time": "P2 Time", "Gap": "P2 Gap", "Laps": "P2 Laps"}, inplace=True)

df_12_7 = pd.read_csv("./data/12_7_df.csv")
df_12_7.set_index('No', inplace=True)

hungary_df = hungary_df.join(df_12_6[['Pos', 'Time', 'Gap', 'Laps']], on='No')
hungary_df.rename(columns={"Pos": "P1 Postition", "Time": "P1 Time", "Gap": "P1 Gap", "Laps": "P1 Laps"}, inplace=True)

hungary_df['Race'] = 'Hungary'

hungary_df.head(5)
# Out:
#     Final Race Position           Driver Name                   Car  \
# No
# 1                     1  Max  Verstappen  VER  Red Bull Racing RBPT
# 44                    2  Lewis  Hamilton  HAM              Mercedes
# 63                    3  George  Russell  RUS              Mercedes
# 55                    4    Carlos  Sainz  SAI               Ferrari
# 11                    5    Sergio  Perez  PER  Red Bull Racing RBPT
#
#     Race Laps    Race Time  Race Points  Fastest Lap No Time of day  \
# No
# 1          70  1:39:35.912           25              45    16:07:26
# 44         70      +7.834s           19              57    16:24:16
# 63         70     +12.337s           15              57    16:24:09
# 55         70     +14.579s           12              51    16:15:54
# 11         70     +15.688s           10              44    16:06:30
#
#    Fastest Lap Time  Avg Speed  Stops Total Pit Time  Starting Grid Pos  \
# No
# ...

# %% [markdown]
# # concat dataframes into 1

# %%
master_pre_clean_df = pd.concat([bahrain_df, saudi_arabia_df, australia_df, italy_df_copy, miami_df, spain_df, monaco_df, azerbaijan_df, canada_df, great_britain_df, austria_df_copy, france_df, hungary_df]).reset_index(drop=True)

# %%
master_pre_clean_df.head()
# Out:
#   Final Race Position            Driver Name           Car  Race Laps  \
# 0                   1  Charles  Leclerc  LEC       Ferrari         57
# 1                   2     Carlos  Sainz  SAI       Ferrari         57
# 2                   3   Lewis  Hamilton  HAM      Mercedes         57
# 3                   4   George  Russell  RUS      Mercedes         57
# 4                   5  Kevin  Magnussen  MAG  Haas Ferrari         57
#
#      Race Time  Race Points  Fastest Lap No Time of day Fastest Lap Time  \
# 0  1:37:33.584           26            51.0    19:31:35         1:34.570
# 1      +5.598s           18            52.0    19:33:13         1:35.740
# 2      +9.675s           15            53.0    19:34:51         1:36.228
# 3     +11.211s           12            56.0    19:39:42         1:36.302
# 4     +14.754s           10            53.0    19:34:54         1:36.623
#
#    Avg Speed  Stops Total Pit Time  Starting Grid Pos  \
# ...

# %%
master_pre_clean_df.to_csv("master_pre_clean.csv", index=False)
